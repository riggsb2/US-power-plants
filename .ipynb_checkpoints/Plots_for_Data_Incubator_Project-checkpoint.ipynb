# %%
from IPython.display import Image

# %% [markdown]
# # Planning the Future of Power
# ## Strategic Model for Optiaml Power Plant Selection
#
# Abtract describing the issue and why forward thinking is necessary. Ideally find an instance where demands were not met or money was lost due to poor planning.
#
# Reference to Figure below

# %% [markdown]
# Plot of Energy production over time based on dataset. Find plot of longer
#
# Preferably I make this with bar stacked part charts under the line. This would

# %%
Image('Energy Demand Projections.png')

# %% [markdown]
# Another representation is to show the fraction of fuel type usage over the years. This, as well as other trends, begs the question of why?

# %%
Image("Results/State Portfolios/Entire US portfolio.png")

# %% [markdown]
# One potential answer is the cost of the fuel. I can make an interactive plot showing the distribution of the cost of fuel over time. Some summary metrics would also be good to quantify the trends

# %% [markdown]
# Future goals and workflow schematic for the project going forward. Maybe insert a couple graphics.
